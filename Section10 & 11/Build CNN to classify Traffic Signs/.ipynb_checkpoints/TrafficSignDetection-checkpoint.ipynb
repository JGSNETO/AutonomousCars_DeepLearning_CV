# %%
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import TensorBoard
import matplotlib.pyplot as plt
import warnings
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
warnings.filterwarnings("ignore")

# %%
with open("./traffic-signs-data/train.p", mode = 'rb') as training_data:
    train = pickle.load(training_data)
with open("./traffic-signs-data/valid.p", mode = 'rb') as validation_data:
    valid = pickle.load(validation_data)
with open("./traffic-signs-data/test.p", mode = 'rb') as testing_data:
    test = pickle.load(testing_data)

# %%
X_train, y_train = train['features'], train['labels']
X_validation, y_validation = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %%
X_train.shape
# Out:
# (34799, 32, 32, 3)

# %%
y_train.shape
# Out:
# (34799,)

# %%
i = 1001
plt.imshow(X_train[i])
y_train[i]
# Out:
# 36

# %%
X_train, y_train = shuffle(X_train, y_train)

# %%
X_train_gray = np.sum(X_train/3, axis=3, keepdims = True)
X_test_gray = np.sum(X_test/3, axis = 3, keepdims = True)
X_validation_gray = np.sum(X_validation/3, axis=3, keepdims = True)

# %%
X_train_gray_norm = (X_train_gray - 128)/128
X_test_gray_norm = (X_test_gray -128)/128
X_validation_gray_norm = (X_validation_gray - 128)/128

# %%
X_train_gray.shape
# Out:
# (34799, 32, 32, 1)

# %%
i = 610
plt.imshow(X_train_gray[i].squeeze(), cmap = 'gray')
plt.figure()
plt.imshow(X_train[i])

# %%
image_shape = X_train_gray[i].shape

# %%
cnn_model = Sequential()
cnn_model.add(Conv2D(32, 3, 3, input_shape = image_shape, activation = 'relu'))
cnn_model.add(MaxPooling2D(pool_size = (2, 2)))
cnn_model.add(Flatten())
cnn_model.add(Dense(32, activation = 'relu'))
cnn_model.add(Dense(43, activation = 'sigmoid'))

# %%
cnn_model.compile(loss='sparse_categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
history = cnn_model.fit(X_train_gray_norm,
                        y_train,
                        batch_size = 500,
                        epochs = 50, 
                        verbose = 1, 
                        validation_data= (X_validation_gray_norm, y_validation))
# Out:
# Epoch 1/50
# 70/70 [==============================] - 1s 11ms/step - loss: 3.4441 - accuracy: 0.0968 - val_loss: 3.4057 - val_accuracy: 0.1190
# Epoch 2/50
# 70/70 [==============================] - 1s 9ms/step - loss: 2.9688 - accuracy: 0.2431 - val_loss: 2.9794 - val_accuracy: 0.2261
# Epoch 3/50
# 70/70 [==============================] - 1s 9ms/step - loss: 2.4343 - accuracy: 0.3654 - val_loss: 2.5316 - val_accuracy: 0.3327
# Epoch 4/50
# 70/70 [==============================] - 1s 9ms/step - loss: 2.0091 - accuracy: 0.4663 - val_loss: 2.2267 - val_accuracy: 0.3952
# Epoch 5/50
# 70/70 [==============================] - 1s 9ms/step - loss: 1.7262 - accuracy: 0.5292 - val_loss: 1.9975 - val_accuracy: 0.4497
# Epoch 6/50
# 70/70 [==============================] - 1s 9ms/step - loss: 1.5138 - accuracy: 0.5850 - val_loss: 1.8142 - val_accuracy: 0.5002
# Epoch 7/50
# 70/70 [==============================] - 1s 9ms/step - loss: 1.3684 - accuracy: 0.6196 - val_loss: 1.7188 - val_accuracy: 0.5322
# Epoch 8/50
# 70/70 [==============================] - 1s 10ms/step - loss: 1.2476 - accuracy: 0.6533 - val_loss: 1.6227 - val_accuracy: 0.5388
# Epoch 9/50
# 70/70 [==============================] - 1s 9ms/step - loss: 1.1601 - accuracy: 0.6758 - val_loss: 1.5589 - val_accuracy: 0.5721
# Epoch 10/50
# 70/70 [==============================] - 1s 9ms/step - loss: 1.0815 - accuracy: 0.6973 - val_loss: 1.4817 - val_accuracy: 0.6154
# Epoch 11/50
# 70/70 [==============================] - 1s 9ms/step - loss: 1.0232 - accuracy: 0.7134 - val_loss: 1.4644 - val_accuracy: 0.5975
# Epoch 12/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.9698 - accuracy: 0.7297 - val_loss: 1.4218 - val_accuracy: 0.6116
# Epoch 13/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.9266 - accuracy: 0.7387 - val_loss: 1.3742 - val_accuracy: 0.6177
# Epoch 14/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.8824 - accuracy: 0.7527 - val_loss: 1.3480 - val_accuracy: 0.6329
# Epoch 15/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.8463 - accuracy: 0.7640 - val_loss: 1.3443 - val_accuracy: 0.6408
# Epoch 16/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.8144 - accuracy: 0.7719 - val_loss: 1.2892 - val_accuracy: 0.6583
# Epoch 17/50
# 70/70 [==============================] - 1s 10ms/step - loss: 0.7879 - accuracy: 0.7793 - val_loss: 1.2813 - val_accuracy: 0.6465
# Epoch 18/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.7622 - accuracy: 0.7876 - val_loss: 1.2421 - val_accuracy: 0.6628
# Epoch 19/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.7325 - accuracy: 0.7948 - val_loss: 1.2488 - val_accuracy: 0.6719
# Epoch 20/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.7116 - accuracy: 0.8026 - val_loss: 1.1991 - val_accuracy: 0.6853
# Epoch 21/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6952 - accuracy: 0.8056 - val_loss: 1.1861 - val_accuracy: 0.6957
# Epoch 22/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6813 - accuracy: 0.8093 - val_loss: 1.2104 - val_accuracy: 0.6757
# Epoch 23/50
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6587 - accuracy: 0.8159 - val_loss: 1.1897 - val_accuracy: 0.6887
# Epoch 24/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6426 - accuracy: 0.8193 - val_loss: 1.1980 - val_accuracy: 0.6930
# Epoch 25/50
# 70/70 [==============================] - 1s 10ms/step - loss: 0.6287 - accuracy: 0.8239 - val_loss: 1.1785 - val_accuracy: 0.7032
# Epoch 26/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.6090 - accuracy: 0.8322 - val_loss: 1.1815 - val_accuracy: 0.6900
# Epoch 27/50
# 70/70 [==============================] - 1s 10ms/step - loss: 0.5927 - accuracy: 0.8357 - val_loss: 1.1803 - val_accuracy: 0.7100
# Epoch 28/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.5876 - accuracy: 0.8348 - val_loss: 1.1529 - val_accuracy: 0.7125
# Epoch 29/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.5728 - accuracy: 0.8410 - val_loss: 1.1614 - val_accuracy: 0.6939
# Epoch 30/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.5646 - accuracy: 0.8424 - val_loss: 1.1352 - val_accuracy: 0.7102
# Epoch 31/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.5496 - accuracy: 0.8488 - val_loss: 1.1142 - val_accuracy: 0.7331
# Epoch 32/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.5408 - accuracy: 0.8496 - val_loss: 1.1446 - val_accuracy: 0.7188
# Epoch 33/50
# 70/70 [==============================] - 1s 10ms/step - loss: 0.5312 - accuracy: 0.8505 - val_loss: 1.1499 - val_accuracy: 0.7175
# Epoch 34/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.5222 - accuracy: 0.8535 - val_loss: 1.1218 - val_accuracy: 0.7259
# Epoch 35/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.5071 - accuracy: 0.8607 - val_loss: 1.1212 - val_accuracy: 0.7211
# Epoch 36/50
# 70/70 [==============================] - 1s 10ms/step - loss: 0.4967 - accuracy: 0.8641 - val_loss: 1.0837 - val_accuracy: 0.7299
# Epoch 37/50
# 70/70 [==============================] - 1s 11ms/step - loss: 0.4966 - accuracy: 0.8634 - val_loss: 1.1029 - val_accuracy: 0.7327
# Epoch 38/50
# 70/70 [==============================] - 1s 10ms/step - loss: 0.4865 - accuracy: 0.8657 - val_loss: 1.1114 - val_accuracy: 0.7249
# Epoch 39/50
# 70/70 [==============================] - 1s 9ms/step - loss: 0.4824 - accuracy: 0.8657 - val_loss: 1.1256 - val_accuracy: 0.7170
# Epoch 40/50
# 70/70 [==============================] - 1s 13ms/step - loss: 0.4715 - accuracy: 0.8700 - val_loss: 1.1024 - val_accuracy: 0.7277
# Epoch 41/50
# 70/70 [==============================] - 1s 11ms/step - loss: 0.4645 - accuracy: 0.8713 - val_loss: 1.0856 - val_accuracy: 0.7295
# Epoch 42/50
# 70/70 [==============================] - 1s 11ms/step - loss: 0.4521 - accuracy: 0.8760 - val_loss: 1.1192 - val_accuracy: 0.7163
# Epoch 43/50
# 70/70 [==============================] - 1s 13ms/step - loss: 0.4465 - accuracy: 0.8786 - val_loss: 1.1197 - val_accuracy: 0.7351
# Epoch 44/50
# 70/70 [==============================] - 1s 12ms/step - loss: 0.4444 - accuracy: 0.8765 - val_loss: 1.1235 - val_accuracy: 0.7295
# Epoch 45/50
# 70/70 [==============================] - 1s 12ms/step - loss: 0.4381 - accuracy: 0.8784 - val_loss: 1.0798 - val_accuracy: 0.7519
# Epoch 46/50
# 70/70 [==============================] - 1s 11ms/step - loss: 0.4302 - accuracy: 0.8814 - val_loss: 1.0830 - val_accuracy: 0.7383
# Epoch 47/50
# 70/70 [==============================] - 1s 12ms/step - loss: 0.4231 - accuracy: 0.8838 - val_loss: 1.0969 - val_accuracy: 0.7390
# Epoch 48/50
# 70/70 [==============================] - 1s 11ms/step - loss: 0.4246 - accuracy: 0.8819 - val_loss: 1.0841 - val_accuracy: 0.7476
# Epoch 49/50
# 70/70 [==============================] - 1s 11ms/step - loss: 0.4129 - accuracy: 0.8872 - val_loss: 1.0875 - val_accuracy: 0.7546
# Epoch 50/50
# 70/70 [==============================] - 1s 11ms/step - loss: 0.4080 - accuracy: 0.8888 - val_loss: 1.0597 - val_accuracy: 0.7417

# %%
score = cnn_model.evaluate(X_test_gray_norm, y_test, verbose = 0)
print('Test Accuracy: {:.4f}'.format(score[1]))
# Out:
# Test Accuracy: 0.7255

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'bo', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()
