# %%
import cv2
import numpy as np
import matplotlib.image as mpimg
from matplotlib import pyplot as plt

# %%
image_color = cv2.imread('chessboard.jpg')
cv2.imshow('Chessboard', image_color)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
# Convert to grayscale
image_gray = cv2.cvtColor(image_color, cv2.COLOR_BGR2GRAY)

corners = cv2.cornerHarris(image_gray, 5,3,0.1)
plt.imshow(corners, cmap = 'gray')
plt.show()

# %%
corners_dilate = cv2.dilate(corners, np.ones((8,8), np.uint8), iterations = 1)
plt.imshow(corners_dilate, cmap = 'gray')
plt.show()

# %%
image_color[corners_dilate > 0.01 * corners_dilate.max()] = [0,255,0]
cv2.imshow('Image with corners', image_color)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # Lets get corner of a truck

# %%
image_color = cv2.imread('truckrr.png')

cv2.imshow('Find truck corners', image_color)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
# Convert to Gray Scale
image_gray = cv2.cvtColor(image_color, cv2.COLOR_BGR2GRAY)
plt.imshow(image_gray, cmap = 'gray')

# %%
corners = cv2.cornerHarris(image_gray, 7, 5, 0.2)
corners_dilate = cv2.dilate(corners, np.ones((8,8), np.uint8), iterations = 1 )

# %%
plt.imshow(corners, cmap = 'gray')
plt.show()

# %%
plt.imshow(corners_dilate, cmap = 'gray')

# %%
image_color_corners = image_color.copty
