# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
import cv2

image = cv2.imread('Speed_Sign_View_2.jpg')
cv2.imshow('Speed_Sign_View_2', image)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
image = mpimg.imread('Speed_Sign_View_2.jpg')
plt.imshow(image)

# %%
# Get the reference points manually

height, width = image.shape[:2]

# %%
height
# Out:
# 600

# %%
width
# Out:
# 800

# %%
# First entry: top-left
# Second entry: top-right
# Third entry: bottol-right
# Fourth: bottom-left

# Coordinates of the 4 corners of the original image
source_points = np.float32([[200, 60], [450,150], [520,500], [170,470]])

# Coordinates of the 4 corners of the desired output
destination_points = np.float32([[0,0], [width,0], [width, height], [0,height]])

# %%
# Use the two sets of four points to comput
# The perspective transformation matrix

M = cv2.getPerspectiveTransform(source_points, destination_points)

warped = cv2.warpPerspective(image, M, (width, height))
cv2.imshow('Warped Image', warped)
cv2.waitKey(0)
cv2.destroyAllWindows()
